# %%
import pandas as pd
import numpy as np
import statistics
import datetime
import matplotlib.pyplot as plt
import re
import math

# %%
raw = pd.read_csv("data.csv")
# set(raw.columns)

# %%
raw.sample(10)
# Out:
#         KeyNo      Name  TypeId TypeIdName           AcceptDate  \
# 79860  117953       NaN       2          貓  2019-09-07T00:00:00
# 84902  123819       NaN       1          犬  2019-10-14T00:00:00
# 50245   84830       NaN       1          犬  2019-02-20T00:00:00
# 74142  111397       NaN       2          貓  2019-07-30T00:00:00
# 90341  130065       NaN       1          犬  2019-11-18T00:00:00
# 88924  128643       NaN       1          犬  2019-11-08T00:00:00
# 93553  134105  108-0606       1          犬  2019-12-10T00:00:00
# 19506   50804       NaN       2          貓  2018-05-30T00:00:00
# 41030   74546       NaN       1          犬  2018-11-27T00:00:00
# 99075  141363       NaN       2          貓  2020-01-21T00:00:00
#
#               AcceptNum  DistrictTeam DistrictTeamName  Sex SexName  ...  \
# 79860  FAAAG10809070005          1551              太平區    2       母  ...
# 84902           1081138          1320              員山鄉    1       公  ...
# 50245           1080147          1321              冬山鄉    1       公  ...
# 74142   AAADG2019073003          1566              板橋區    2       母  ...
# 90341        S081118-05           302              山上區    1       公  ...
# 88924   QAAAG1081108001          1517              暖暖區    1       公  ...
# 93553   RAAAG1081210007          1524              香山區    2       母  ...
# 19506   AAAEG1070530005          1568              中和區    2       母  ...
# 41030         107112706             9              內湖區    2       母  ...
# 99075  FAAAG10901210008          1532              北屯區    2       母  ...
#
#        VillageID VillageName            FinalDate ErrorMessage Language  \
# 79860     S27001         大興里  2019-09-19T00:00:00          NaN        0
# 84902          0         NaN  2019-10-22T00:00:00          NaN        0
# 50245          0         NaN  2019-04-03T00:00:00          NaN        0
# 74142          0         NaN  2019-09-17T00:00:00          NaN        0
# 90341     U29004         明和里  2019-11-20T00:00:00          NaN        0
# 88924          0         NaN  2020-03-10T00:00:00          NaN        0
# 93553          0         NaN  2020-02-03T00:00:00          NaN        0
# 19506          0         NaN  2018-06-10T00:00:00          NaN        0
# 41030          0         NaN  2019-04-13T00:00:00          NaN        0
# 99075          0         NaN  2020-01-30T00:00:00          NaN        0
#
#        PageSize CurrentPage SortFields  SortDirection RowCount
# 79860      9999           1        NaN            NaN        0
# 84902      9999           1        NaN            NaN        0
# 50245      9999           1        NaN            NaN        0
# 74142      9999           1        NaN            NaN        0
# 90341      9999           1        NaN            NaN        0
# 88924      9999           1        NaN            NaN        0
# 93553      9999           1        NaN            NaN        0
# 19506      9999           1        NaN            NaN        0
# 41030      9999           1        NaN            NaN        0
# 99075      9999           1        NaN            NaN        0
#
# [10 rows x 128 columns]

# %% [markdown]
# # 即便是暫時不適合的動物仍可以領養

# %%
# tmp = [True if x == '暫時不適合' else False for x in raw['AdoptionName']]#{'待認領', '暫時不適合', '適合認養'}
# raw[['AdoptionName','_Situation2Name','AcceptDate','FinalDate','OpenAdoptionTime']][tmp].sample(10)

# %%
#刪掉無資訊、明顯無相關的欄位
saved_columns = [
 'KeyNo',
 'TypeIdName', #('其他', '犬', '貓')
 'AcceptDate', #被領養日期？
 'OpenAdoptionTime',
 'DistrictTeamName',
 'SexName',#{'none', '公', '未知', '母'}
 'ReasonName',#{nan, '不擬續養', '依法沒入', '其他', '動物救援', '拾獲送交', '收容所轉入', '政府捕捉'}
 'VarietyName',#種類，阿富汗、馬爾濟斯...71種，其中兩個是數字268,269
 'VarietyRemark',#更細的種類，沒有救NaN
 'BuildName',#體型名稱{'1', '中', '大', '小'}
 'Bodyweight',#超亂，setlen=12135, nan, NaN, 13~15, 2公斤, 4....
 'Age2Name',#{'1至3月齡', '1至3歲', '3至6月齡', '3至7歲', '6月齡至1歲', '7歲以上', nan, 'none', '未離乳'}
 'CoatName',#毛色，28種，包括'none'
#  'MouthCoat',#亂，nan,'string', '鼻上方有一咖啡色胎記', '黑嘴','黑嘴    '
#  'HeadCoat',# 亂，set多個nan???
#  'ChestCoat',#亂，nan, 'string'...
#  'FootCoat',#亂，nan, 'string'...
#  'EarCoat',# 亂，set多個nan???
#  'BackCoat',# 亂，set多個nan???
#  'TailCoat',#亂，nan,'string',
 'CollarName',#項圈顏色{'none', '其他', '棕色', '無', '白色', '粉紅色', '紅色', '花色', '藍色', '銀色', '黃色', '黑色'}
#  'CollarRemark',#項圈特徵
 'ThoracodorsalName',#胸甲(衣服)顏色{'none', '其他', '棕色', '無', '白色', '紅色', '花色', '藍色', '黃色', '黑色'}
#  'ThoracodorsalRemark',#多，胸甲(衣服)特徵
 'AdoptionName',#{'待認領', '暫時不適合', '適合認養'}
 'NotAdoptionName',#{'none', '健康不適', '動保案件', '年紀不適', '行為不適'}
 '_Situation2Name',#{'none','人道處理其他法令授權','人道處理第12條第1項第3款','人道處理第12條第1項第5款', '人道處理第12條第1項第7款', '其他','原地飭回','收容所轉出','生理耗弱死亡','疾病死亡','認領','認養','逃脫'}
#  'SituationRemark',#認養狀態備註
 'StatusName',#{'sNull', '其他', '原地飭回', '安樂死', '生理耗弱死亡', '疾病死亡', '認領養', '逃跑'}
#  'Address',
 'IsSterilizationName',#{'是', '未確定'}
#  'SterilizationDate',
 'EarNoteName',#{'none', '右剪耳', '左剪耳'}
#  'Note',#超雜
 'LengthCoatName',#{'none', '中長毛', '未修剪過', '短毛', '長毛'}
 'HealthStatusName',#{'none', '其它', '寄生蟲', '正常', '異常', '疫苗'}
#  'HealthStatusRemark',#超多受傷原因
 'Behavior',#幾種數字，但還不知道數字代表的意思
#  'BehaviorRemark',#超多行為描述
#  'InImage',
#  'ImageNameStr',
#  'FrontImageName',
#  'VaccineDate', #沒填示沒打過疫苗？
 'ShelterName',
#  'VillageID',
#  'VillageName',
 'FinalDate'#領養日期
]
raw = raw[saved_columns]

# %%
#dropna columns
dropna_col = ['FinalDate','ReasonName']
# replacenan_col = ['DistrictTeamName', 'VarietyRemark','Bodyweight',
#                   'MouthCoat','HeadCoat','ChestCoat','FootCoat','EarCoat',
#                   'BackCoat','TailCoat','HealthStatusRemark','BehaviorRemark','CollarRemark',
#                   'ThoracodorsalRemark','SituationRemark','Behavior','VillageName']
print("Before rm na:", raw.shape)

for d_col in dropna_col:
    raw=raw[raw[d_col].notna()]
    print(d_col, raw.shape)
raw.fillna('無', inplace=True)
raw.replace('none', '無', inplace=True)
raw['StatusName'].replace('sNull', '無', inplace=True)
print("Aefore rm na:", raw.shape)
# Out:
# Before rm na: (115267, 26)
# FinalDate (115267, 26)
# ReasonName (115261, 26)
# Aefore rm na: (115261, 26)

# %% [markdown]
# 處理 '_Situation2Name'
#
# 1：'認養'
#
# 0:'無'
#
# 刪掉：'人道處理其他法令授權','人道處理第12條第1項第3款','人道處理第12條第1項第5款', '人道處理第12條第1項第7款','其他','原地飭回','收容所轉出','認領','逃脫','生理耗弱死亡','疾病死亡'
#
# #{'none','人道處理其他法令授權','人道處理第12條第1項第3款','人道處理第12條第1項第5款', '人道處理第12條第1項第7款', '其他','原地飭回','收容所轉出','生理耗弱死亡','疾病死亡','認領','認養','逃脫'}

# %%
print(set( raw['_Situation2Name']))
tmp = [True if x in ['無', '認養'] else False for x in raw['_Situation2Name']]
raw = raw[tmp]
tmp = [False if x == "測試收容所" else True for x in raw['ShelterName']]
raw = raw[tmp]
tmp = [False if x == datetime.datetime(1, 1, 1, 0, 0) else True for x in raw['OpenAdoptionTime']]
raw = raw[tmp]
raw['Adopted'] = [1 if x == "認養" else 0 for x in raw['_Situation2Name']]
print('# of adopted: {} \n# of not adopted:{}'.format(sum(raw['Adopted']), len(raw['Adopted'])-sum(raw['Adopted'])))
raw.drop(columns=['_Situation2Name'])
# Out:
# {'人道處理第12條第1項第5款', '逃脫', '人道處理第12條第1項第3款', '其他', '疾病死亡', '生理耗弱死亡', '收容所轉出', '無', '認養', '人道處理其他法令授權', '人道處理第12條第1項第7款', '認領', '原地飭回'}
# # of adopted: 62837
# # of not adopted:8020
#          KeyNo TypeIdName           AcceptDate     OpenAdoptionTime  \
# 1        27025          犬  2017-10-26T00:00:00  2017-10-26T00:00:00
# 3        27027          犬  2017-10-31T00:00:00  2017-10-31T00:00:00
# 4        27034          犬  2017-09-28T00:00:00  2017-09-28T00:00:00
# 5        27035          犬  2015-12-18T00:00:00  2017-12-15T00:00:00
# 6        27036          貓  2017-07-04T00:00:00  2017-07-04T00:00:00
# ...        ...        ...                  ...                  ...
# 115262  160964          犬  2020-05-20T00:00:00  0001-01-01T00:00:00
# 115263  160965          犬  2020-05-20T00:00:00  0001-01-01T00:00:00
# 115264  160966          犬  2020-05-20T00:00:00  0001-01-01T00:00:00
# 115265  160967          犬  2020-05-20T00:00:00  0001-01-01T00:00:00
# 115266  160968          犬  2020-05-25T00:00:00  0001-01-01T00:00:00
#
#        DistrictTeamName SexName ReasonName VarietyName VarietyRemark  \
# 1                   壽豐鄉       公       政府捕捉         混種狗             無
# 3                   瑞穗鄉       公       政府捕捉         混種狗             無
# 4                   秀林鄉       母       政府捕捉         混種狗             無
# 5                   燕巢區       母       政府捕捉         混種狗             無
# 6                   學甲區       母       拾獲送交         混種貓             無
# ...                 ...     ...        ...         ...           ...
# 115262              新市區       公       政府捕捉         混種狗             無
# 115263              新市區       公       政府捕捉         混種狗             無
# 115264              新市區       母       政府捕捉         混種狗             無
# 115265              玉井區       母       政府捕捉         混種狗             無
# 115266              新市區       母       政府捕捉         混種狗             無
#
#        BuildName  ... NotAdoptionName StatusName IsSterilizationName  \
# 1              中  ...               無        認領養                   是
# 3              中  ...               無        認領養                   是
# 4              中  ...               無        認領養                   是
# 5              大  ...               無        認領養                   是
# 6              中  ...               無        認領養                 未確定
# ...          ...  ...             ...        ...                 ...
# 115262         小  ...            動保案件          無                 未確定
# 115263         小  ...            動保案件          無                 未確定
# 115264         小  ...            動保案件          無                 未確定
# 115265         中  ...               無        認領養                 未確定
# 115266         中  ...               無          無                 未確定
#
#        EarNoteName LengthCoatName HealthStatusName    Behavior    ShelterName  \
# 1                無             短毛               正常      83, 85     花蓮縣流浪犬中途之家
# 3                無             短毛               正常  83, 84, 85     花蓮縣流浪犬中途之家
# 4                無              無               正常      83, 85     花蓮縣流浪犬中途之家
# 5                無              無               正常           無  高雄市燕巢動物保護關愛園區
# 6                無              無                無           無     臺南市動物之家善化站
# ...            ...            ...              ...         ...            ...
# 115262           無              無                無           無     臺南市動物之家善化站
# 115263           無              無                無           無     臺南市動物之家善化站
# 115264           無              無                無           無     臺南市動物之家善化站
# 115265           無              無                無           無     臺南市動物之家善化站
# 115266           無              無                無           無     臺南市動物之家善化站
#
#                   FinalDate Adopted
# 1       2018-05-07T00:00:00       1
# 3       2018-04-03T00:00:00       1
# 4       2018-01-24T10:42:04       1
# 5       2018-03-08T00:00:00       1
# 6       2018-01-24T00:00:00       1
# ...                     ...     ...
# 115262  0001-01-01T00:00:00       0
# 115263  0001-01-01T00:00:00       0
# 115264  0001-01-01T00:00:00       0
# 115265  2020-05-21T00:00:00       1
# 115266  0001-01-01T00:00:00       0
#
# [70857 rows x 26 columns]

# %%
#[Staydays]
raw['AcceptDate'] = [datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S") for x in raw['AcceptDate']] 
raw['FinalDate'] = [datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S") for x in raw['FinalDate']] 
raw['OpenAdoptionTime'] = [datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S") for x in raw['OpenAdoptionTime']]

# %%
tmp = [False if x == datetime.datetime(1900, 1, 1, 0, 0) or x ==  datetime.datetime(1, 1, 1, 0, 0) else True for x in raw['OpenAdoptionTime']]
raw = raw[tmp]
print("AcceptDate(min, max):({}, {})".format(min(raw['AcceptDate']), max(raw['AcceptDate'])))
print("FinalDate(min, max):({}, {})".format(min(raw['FinalDate']), max(raw['FinalDate'])))
print("OpenAdoptionTime(min, max):({}, {})".format(min(raw['OpenAdoptionTime']), max(raw['OpenAdoptionTime'])))
# Out:
# AcceptDate(min, max):(0001-01-01 00:00:00, 2020-05-22 00:00:00)
# FinalDate(min, max):(0001-01-01 00:00:00, 2020-05-30 00:00:00)
# OpenAdoptionTime(min, max):(2012-09-15 00:00:00, 2020-06-10 00:00:00)

# %%
print("Accept:", sum([True if x == datetime.datetime(1, 1, 1, 0, 0) else False for x in raw['AcceptDate']]))
print("Final:", sum([True if x == datetime.datetime(1, 1, 1, 0, 0) else False for x in raw['FinalDate']]))
print("OpenAdoptionTime:", sum([True if x == datetime.datetime(1, 1, 1, 0, 0) else False for x in raw['OpenAdoptionTime']]))
# Out:
# Accept: 5
# Final: 4385
# OpenAdoptionTime: 0

# %%
# tmp = [False if x == datetime.datetime(1, 1, 1, 0, 0) else True for x in raw['AcceptDate']]
# raw = raw[tmp]
print("不合理（領養日期<開放領養日期且已被領養）：",sum([True if x<y and z == 1 else False for x,y,z in zip(raw['FinalDate'],raw['OpenAdoptionTime'],raw['Adopted'])]))
tmp = [True if z == 1 and x == datetime.datetime(1,1,1,0,0) else False for x,y,z in zip(raw['FinalDate'],raw['OpenAdoptionTime'],raw['Adopted'])]
print("不合理（領養日期無料且已被領養）：",sum(tmp))
print("當天領走(領養日期==開放領養日期）：",sum([True if x==y else False for x,y in zip(raw['FinalDate'],raw['OpenAdoptionTime'])]))
print("合理（領養日期>開放領養日期且已被領養）：",sum([True if x>y and z == 1 else False for x,y,z in zip(raw['FinalDate'],raw['OpenAdoptionTime'],raw['Adopted'])]))
print("不合理（領養日期>=開放領養日期且未被領養）：",sum([True if x>=y and z == 0 else False for x,y,z in zip(raw['FinalDate'],raw['OpenAdoptionTime'],raw['Adopted'])]))
# Out:
# 不合理（領養日期<開放領養日期且已被領養）： 929
# 不合理（領養日期無料且已被領養）： 11
# 當天領走(領養日期==開放領養日期）： 9583
# 合理（領養日期>開放領養日期且已被領養）： 30239
# 不合理（領養日期>=開放領養日期且未被領養）： 1

# %%
# tmp = [True if x>y and z == 0 else False for x,y,z in zip(raw['AcceptDate'],raw['OpenAdoptionTime'],raw['Adopted'])]
tmp = [True if x<y and z == 1 else False for x,y,z in zip(raw['FinalDate'],raw['OpenAdoptionTime'],raw['Adopted'])]
raw[['Adopted','AcceptDate','OpenAdoptionTime']][tmp]
# print("不合理（領養日期<開放領養日期且已被領養）：",sum([True if x<y and z == 1 else False for x,y,z in zip(raw['AcceptDate'],raw['OpenAdoptionTime'],raw['Adopted'])]))
raw['KeyNo'][tmp]
# Out:
# 461        27554
# 647        27795
# 846        28018
# 1001       28202
# 1005       28206
#            ...
# 114880    160582
# 114882    160584
# 114883    160585
# 115028    160730
# 115032    160734
# Name: KeyNo, Length: 929, dtype: int64

# %%
raw["StayDays"] = raw["FinalDate"]-raw['AcceptDate']
raw['StayDays'] = [x.days for x in raw['StayDays']] 
#[Staydays] 清掉未被領養的資料
# raw = raw[raw['StayDays']>=0]
# raw['StayDays'] = ["未被領養" if x < 0 else x for x in raw['StayDays']]
print(sorted(raw['StayDays'][raw['Adopted'] == 0]))
# raw.drop(columns=['AcceptDate', 'FinalDate'], inplace=True)

#[SexName]clean
raw["SexName"].replace({"none": "未知"}, inplace=True)
#VarietyName=>268,269清掉？

#[BuildName]clean
raw = raw[raw["BuildName"] != '1']
#[VarietyRemark]clean
tmp = [False if x in ['0','MIX','mix','string'] else True for x in raw['VarietyRemark']]
raw = raw[tmp]

print("After cleaning dirty data:", raw.shape)
# Out:
# [-737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737565, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737564, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737563, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737562, -737561, -737561, -737561, -737561, -737560, -737560, -737560, -737560, -737560, -737560, -737560, -737560, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737559, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737558, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737557, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737556, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737555, -737554, -737554, -737554, -737554, -737554, -737554, -737554, -737554, -737553, -737553, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -737552, -73 ...
# After cleaning dirty data: (45264, 28)

# %%
# data = [x for x in raw['StayDays'] if x  != "未被領養"]
# plt.hist(data)
# sorted(raw['AcceptDate'])
# sum([True if x == datetime.datetime(1, 1, 1, 0, 0) else False for x in raw['AcceptDate']])

# %%
#[Bodyweight]clean
tmp = [False if x in ['strin','東22','１',''] else True for x in raw['Bodyweight']]
raw = raw[tmp]
raw['Bodyweight'] = [str(x).replace('K', '').replace('G', '').replace('k', '').replace('g', '').replace('<', '').replace('-', '~').replace('ｋｇ', '').replace('公斤', '').replace('以上', '').replace('以下', '').replace('體重', '').replace('胖', '20').strip(". ") for x in raw['Bodyweight']]
tmp = []
for x in raw['Bodyweight']:
        if x == "無" or x == '':
            tmp.append("無")
            continue
        if x.find("~") != -1:
            tmp.append(statistics.mean([float(y) for y in x.split("~")]))
        else:
            tmp.append(float(x))
raw['Bodyweight'] = tmp
#[Bodyweight]remove outlier
tmp = np.array([x for x in tmp if x != "無"])
Q1= np.mean(tmp)-2*np.std(tmp)
Q3= np.mean(tmp)+2*np.std(tmp)
raw = raw[[True if x == "無" or (x >= Q1 and x <= Q3) else False for x in raw['Bodyweight']]]
#[Bodyweight]convert to category(0~5, 5~10, 10~15...20以上)
tmp = []
for x in raw['Bodyweight']:
    if x == "無":
        tmp.append("無")
    elif x > 0 and x <= 5:
        tmp.append("0~5")
    elif x > 5 and x <= 10:
        tmp.append("5~10")
    elif x > 10 and x <= 15:
        tmp.append("10~15")
    elif x > 15 and x <= 20:
        tmp.append("15~20")
    else:
        tmp.append("20以上")
raw['Bodyweight'] = tmp

print("After cleaning dirty data:", raw.shape)
# Out:
# After cleaning dirty data: (45248, 28)

# %%
tmp = [True if x not in ["年老", "廠商測試","品種說明","銀","白底，頭尾有花色"] else False for x in raw['VarietyRemark']]
raw = raw[tmp]
raw["VarietyRemark"] = [s.strip().replace("混", "").replace("似", "").replace(" ", "").replace('可能到','').replace("有到","").replace("很像","").replace("微","").replace("疑到","").replace("類","") for s in raw['VarietyRemark']]
raw['VarietyRemark'] = ["種犬" if (x == "種品種犬" or x == "種狗") else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["種貓" if (x == "種貓(美短+豹貓)") else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = [x if (x == "種犬" or x == "種貓") else x.replace("種","") for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["暹羅貓" if x == "暹羅" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["柴犬" if x == "柴" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["拉不拉多" if x == "拉不拉" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["梗犬" if (x == "梗" or x == "梗血統") else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["鵝" if x == "鵝4隻" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["和尚鸚鵡" if x == "和尚" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["查理士" if x == "查理氏" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["喜馬拉雅貓" if x == "喜馬拉雅" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["比特犬" if x == "比特" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["鬥牛犬" if x == "鬥牛" else x for x in raw['VarietyRemark']]
raw['VarietyRemark'] = ["高加索犬" if x == "高加索" else x for x in raw['VarietyRemark']]

tmp = [True if x not in ["","黑色","美短","小型"] else False for x in raw['VarietyRemark']]
tmp = [True if x!="" else False for x in raw['VarietyRemark']]
raw = raw[tmp]
print(set(raw['VarietyRemark']))
# Out:
# {'狼犬哈士奇', '羊', '美短', '長毛臘腸犬', '秋田', '黑色', '長毛臘腸', '波斯', '鴿子', '喜馬拉雅貓', '梗犬', '蜜袋鼯', '狐狸犬', '黑色貴賓', '異國短毛貓', '黑貴賓', '西施', '蝴蝶犬+吉娃娃', '柴犬', '吉娃娃約克夏', '鵝', '高砂犬', '迷你杜檳', '潘布魯克', '累杜賓犬', '小太陽', '高加索犬', '黑豬', '哈士奇', '牧羊犬', '美國惡霸', '蘇格蘭梗', '暹羅貓', '三花', '奶油貴賓', '土狼犬', '挪威森林貓', '小杜賓', '德國狼犬', '加菲貓', '牛頭梗', '種貓', '比利時狼犬', '獒犬', '拉不拉多', '麝香豬', '雪納瑞', '臘腸', '法鬥貴賓', '迷你杜賓', '紅貴賓', '靈緹', '藍貓', '高山犬', '吉娃娃', '米格魯', '小型', '比特波士頓犬', '長毛吉娃娃', '蛇', '高山比特', '短毛臘腸', '種犬', '貴賓', '米克斯', '和尚鸚鵡', '鴨', '無', '鬥牛犬', '尋血犬', '狼犬', '比特犬', '長毛', '金吉拉', '可麗牧羊犬', '黑梗犬'}

# %% [markdown]
# # Coat 如何切分特徵，同時有多個特徵？
#
# ### 橘貓很受歡迎？？？

# %%
# #ChestCoat
# raw['ChestCoat'] = ["白毛" if x.find("白")!=-1 else x for x in raw['ChestCoat']] #496 objs
# raw['ChestCoat'] = ["黃毛" if x.find("黃")!=-1 else x for x in raw['ChestCoat']] #7 objs
# raw['ChestCoat'] = ["棕黑毛" if re.search('咖啡|黑|棕', x) else x for x in raw['ChestCoat']] #9 objs
# raw['ChestCoat'] = [x if (x == "無" or re.search('白毛|黃毛|棕黑毛', x)) else "其他" for x in raw['ChestCoat']]
# print("ChestCoat:")
# for i in set(raw['ChestCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['ChestCoat']]))
# print()

# #MouthCoat
# raw['MouthCoat'] = ["白" if x.find("白")!=-1 else x for x in raw['MouthCoat']] #117 objs
# raw['MouthCoat'] = ["黃" if x.find("黃")!=-1 else x for x in raw['MouthCoat']] #9 objs
# raw['MouthCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x) else x for x in raw['MouthCoat']] #242 objs
# raw['MouthCoat'] = [x if (x == "無" or re.search('白|黃|棕灰黑', x)) else "其他" for x in raw['MouthCoat']]
# print("MouthCoat:")
# for i in set(raw['MouthCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['MouthCoat']]))
# print()

# #HeadCoat
# raw['HeadCoat'] = ["虎斑" if re.search('虎斑|虎班', x) else x for x in raw['HeadCoat']] #23 objs
# raw['HeadCoat'] = ["黑白" if re.search('黑.*白', x) else x for x in raw['HeadCoat']] #4 objs
# raw['HeadCoat'] = ["棕灰黑" if (re.search('咖啡|黑|棕|灰', x) and x != "黑白") else x for x in raw['HeadCoat']] #41 objs
# raw['HeadCoat'] = ["受傷" if re.search('傷|浮腫|受傷|車禍|獨眼|白內障', x) else x for x in raw['HeadCoat']] #10 objs
# raw['HeadCoat'] = ["四眼" if re.search('四目|四眼', x) else x for x in raw['HeadCoat']] #66 objs
# raw['HeadCoat'] = ["白" if (x.find("白")!=-1 and x != "黑白") else x for x in raw['HeadCoat']] #18 objs
# raw['HeadCoat'] = ["黃" if x.find("黃")!=-1 else x for x in raw['HeadCoat']] #29 objs
# raw['HeadCoat'] = [x if (x == "無" or re.search('虎斑|黑白|棕灰黑|受傷|四眼|白|黃', x)) else "其他" for x in raw['HeadCoat']]
# print("HeadCoat:")
# for i in set(raw['HeadCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['HeadCoat']]))
# print()

# #FootCoat
# raw['FootCoat'] = ["受傷" if re.search('傷|截|不良於行|骨折|斷裂|缺|腫瘤|斷|脫臼|尺骨外露|跛行|三腳|後癱|癱瘓|畸形|短|無力', x) else x for x in raw['FootCoat']] #10 objs
# raw['FootCoat'] = ["虎斑" if re.search('虎斑|虎班|斑紋', x) else x for x in raw['FootCoat']] #23 objs
# raw['FootCoat'] = ["白" if x.find("白")!=-1 else x for x in raw['FootCoat']] #18 objs
# raw['FootCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x) else x for x in raw['FootCoat']] #23 objs
# raw['FootCoat'] = ["黃" if x.find("黃")!=-1 else x for x in raw['FootCoat']] #18 objs
# raw['FootCoat'] = [x if (x == "無" or re.search('虎斑|白|棕灰黑|受傷|黃', x)) else "其他" for x in raw['FootCoat']]
# print("FootCoat:")
# for i in set(raw['FootCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['FootCoat']]))
# print()

# #EarCoat
# raw['EarCoat'] = ["剪/缺/折/立/垂耳" if re.search('垂|剪|折|缺|立|摺|聳', x) else x for x in raw['EarCoat']] #10 objs
# raw['EarCoat'] = ["受傷" if re.search('左耳皺|皮膚炎|長瘤', x) else x for x in raw['EarCoat']] #23 objs
# raw['EarCoat'] = ["虎斑" if re.search('虎斑|虎班|斑紋', x) else x for x in raw['EarCoat']] #23 objs
# raw['EarCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x) else x for x in raw['EarCoat']] #23 objs
# raw['EarCoat'] = ["黃" if x.find("黃")!=-1 else x for x in raw['EarCoat']] #18 objs
# raw['EarCoat'] = [x if (x == "無" or re.search('虎斑|缺|棕灰黑|受傷|黃', x)) else "其他" for x in raw['EarCoat']]
# print("EarCoat:")
# for i in set(raw['EarCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['EarCoat']]))
# print()

# #BackCoat
# raw['BackCoat'] = ["受傷" if re.search('皮膚病|傷|突出物', x) else x for x in raw['BackCoat']]
# raw['BackCoat'] = ["斑點" if re.search('虎斑|虎班|斑紋|斑', x) else x for x in raw['BackCoat']]
# raw['BackCoat'] = ["白" if re.search('白', x) else x for x in raw['BackCoat']]
# raw['BackCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x)  else x for x in raw['BackCoat']] 
# raw['BackCoat'] = [x if (x == "無" or re.search('斑點|棕灰黑|受傷|白', x)) else "其他" for x in raw['BackCoat']]
# print("BackCoat:")
# for i in set(raw['BackCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['BackCoat']]))
# print()

# #TailCoat
# raw['TailCoat'] = ["有病" if re.search('皮膚病|肉瘤', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["截尾" if re.search('截|剪尾|半短|折尾|斷|短|半尾', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["無尾" if re.search('無尾', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["斑點" if re.search('虎斑|虎班|斑紋|斑', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["麒麟尾" if re.search('麒麟', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["鐮刀尾" if re.search('鐮刀', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["白" if re.search('白', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x)  else x for x in raw['TailCoat']] 
# raw['TailCoat'] = [x if (x == "無" or re.search('斑點|棕灰黑|有病|白|截尾|無尾|麒麟尾|鐮刀尾', x)) else "其他" for x in raw['TailCoat']]
# print("TailCoat:")
# set(raw['TailCoat'])
# for i in set(raw['TailCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['TailCoat']]))
# print()

# %%
#有無項圈
raw['CollarName'] = ["無項圈" if x == "無" else "有項圈" for x in raw['CollarName']]
#有無衣服
raw['ThoracodorsalName'] = ["無衣服" if x == "無" else "有衣服" for x in raw['ThoracodorsalName']]

# %% [markdown]
# # NotAdoptionName有標注的欄位都刪掉？ //欄位留著

# %%
#每隻動物都被領養了嗎？？？因為有NotAdoptionName這個欄位
# print(set(raw['NotAdoptionName']))
# raw = raw[raw['NotAdoptionName']=='無']
# print("rm [NotAdoptionName], data shape", raw.shape)

# %% [markdown]
# # SituationRemark有標注的欄位都刪掉？ ////欄位刪掉

# %%
# print(set(raw['SituationRemark']))
# raw = raw[raw['SituationRemark']=='無']
# print("rm [SituationRemark], data shape", raw.shape)

# %% [markdown]
# # IsSterilizationName'填的有{'是', '未確定'}，填是的有14834筆，SterilizationDate 有填的9961筆
#
#
# ### 要保留IsSterilizationName這個欄位就好嗎？

# %%
# print(sum([True if x!='0001-01-01T00:00:00' else False for x in raw['SterilizationDate']]))
# print(sum([True if x=='是' else False for x in raw['IsSterilizationName']]))
# set(raw['SterilizationDate'])

# %% [markdown]
# #  備註欄位直接刪掉？內容大致為三類（病因、外觀、各種阿里阿咂），其中病因佔多數

# %%
# print(sum([True if x=='無' else False for x in raw['Note']]))
# set(raw['Note'])

# %%
# set(raw['HealthStatusName'])
# print(sum([True if x=='無' else False for x in raw['HealthStatusName']]))

# %% [markdown]
# #  健康狀態備註欄位直接刪掉？
# - 絕育(佔多數)(紮)
# - 病因or缺陷
# - 疫苗（CCV\CPV\FIV\五合一）
# - 驅蟲藥
# - 幼犬奶貓

# %%
# set(raw['HealthStatusRemark'])
# print(sum([True if x=='無' else False for x in raw['HealthStatusRemark']]))

# %% [markdown]
# # [Behavior]可以有多種category，切成01表

# %%
tmp = []
for a in raw['Behavior']:
    tmp += [x for x in a.split(", ")]
health_types = set(tmp)
for i in health_types:
    health_types_col = []
    for a in raw['Behavior']:
        if i in a:
            health_types_col.append(1)
        else:
            health_types_col.append(0)
    raw['Behavior'+i] = health_types_col
raw.drop(columns=['Behavior','Behavior無'], inplace=True)

# %%
raw['SexName'].replace('未知', '無', inplace=True)
tmp = [True if x not in ["268", "269"] else False for x in raw['VarietyName'] ]
raw = raw[tmp]

# %%
file = open('clean2_description.txt', 'w')
file.write('# of columns:'+str(len(raw.columns)))
raw = raw.astype(str)
for col in raw.columns:
    if col in ['ＳInImage','ImageNameStr','FrontImageName']:
        continue
    print(col+' : ', set(raw[col]))
    file.write(col+' : '+', '.join(list(set(raw[col])))+'\n')
#     print(i, sum([True if re.search(i, x) else False for x in raw['TailCoat']]))
file.write("# of adopted data:{}".format(sum(raw['Adopted']=='1'))+'\n')
file.write("# of not adopted data:{}".format(sum(raw['Adopted']=='0'))+'\n')
file.close()
raw.to_csv('clean2.csv', index=False)
# Out:
'冬山鄉', '綠島鄉', '中和區', '尖石鄉', '新莊區', '花壇鄉', '延平鄉', '豐濱鄉', '無', '南州鄉', '斗六市', '二崙鄉', '橫山鄉', '復興區', '竹北市', '和平區', '義竹鄉', '獅潭鄉', '霧峰區', '埔心鄉', '集集鎮', '水里鄉', '新營區', '大湖鄉', '楊梅區', '芳苑鄉', '永康區', '安平區', '瑞芳區', '旗山區', '泰安鄉', '甲仙區', '公館鄉', '秀林鄉', '內門區', '北區', '朴子市', '八里區', '恆春鎮', '莿桐鄉', '岡山區', '大埤鄉', '枋寮鄉', '竹南鎮', '金湖鎮', '烏坵鄉', '雙溪區', '大雅區', '美濃區', '安樂區', '田中鎮', '小港區', '名間鄉', '竹山鎮', '獅子鄉', '新埔鎮', '麟洛鄉', '南庄鄉', '太保市', '桃源區', '里港鄉', '北門區', '龍潭區', '卓蘭鎮', '草屯鎮', '蘆洲區', '烈嶼鄉', '仁愛鄉', '善化區', '那瑪夏區', '鶯歌區', '麥寮鄉', '深坑區', '埔里鎮', '頭屋鄉', '東區', '田尾鄉', '枋山鄉', '萬丹鄉', '潭子區', '大林鎮', '白河區', '信義鄉', '南屯區', '茂林區', '仁愛區', '阿里山鄉', '芬園鄉', '將軍區', '其他', '平鎮區', '楠梓區', '鼓山區', '臺東市', '寶山鄉', '左鎮區', '南區', '鹿港鎮', '泰山區', '北斗鎮', '玉里鎮', '南化區', '仁武區', '礁溪鄉', '中正區', '石岡區', '貢寮區', '林內鄉', '卑南鄉', '平溪區', '大里區', '梧棲區', '左營區', '阿蓮區', '屏東市', '西湖鄉', '光復鄉', '大同區', '斗南鎮', '北港鎮', '香山區', '吉安鄉', '新城鄉', '埤頭鄉', '內埔鄉', '口湖鄉', '六龜區', '五股區', '金峰鄉', '新興區', '后里區', '外埔區', '神岡區', '望安鄉', '後壁區', '峨眉鄉', '新化區', '大社區', '永和區', '林園區', '玉井區', '田寮區', '樹林區', '苗栗市', '前金區', '萬榮鄉', '新市區', '鳳山區', '湖西鄉', '歸仁區', '海端鄉', '布袋鎮', '潮州鎮', '車城鄉', '汐止區', '三芝區', '東引鄉', '東河鄉', '五結鄉', '二水鄉', '苑裡鎮', '石碇區', '鹿谷鄉', '關廟區', '南投市', '彌陀區', '觀音區', '永安區', '元長鄉'}
# SexName :  {'無', '公', '母'}
# ReasonName :  {'動物救援', '拾獲送交', '其他', '收容所轉入', '不擬續養', '依法沒入', '政府捕捉'}
# VarietyName :  {'可卡', '英國藍貓', '喜樂蒂', '比熊', '俄羅斯藍貓', '其他貓', '狐狸', '敖犬', '秋田', '寵物鼠', '美國短毛貓', '波斯', '柯基', '梗犬', '鬆獅犬', '混種', '比特', '西施', '柴犬', '傑克羅素', '豹貓', '約克夏', '哈士奇', '暹羅貓', '西高地白梗', '英國查理士獵犬', '拉布拉多', '古代牧羊犬', '英國短毛貓', '獵狐梗', '折耳貓', '加菲貓', '迷你品', '牛頭梗', '蝴蝶犬', '杜賓', '英國鬥牛犬', '雪納瑞', '臘腸', '混種貓', '挪威納', '混種狗', '高山犬', '吉娃娃', '馬爾濟斯', '米格魯', '法國鬥牛犬', '寵物兔', '拉薩', '巴戈', '其他犬', '貴賓', '邊境牧羊犬', '北京犬', '黃金獵犬', '波士頓', '美國鬥牛犬', '狼犬', '金吉拉', '博美', '拳師犬'}
# VarietyRemark :  {'狼犬哈士奇', '羊', '美短', '長毛臘腸犬', '秋田', '黑色', '長毛臘腸', '波斯', '鴿子', '喜馬拉雅貓', '梗犬', '蜜袋鼯', '狐狸犬', '黑色貴賓', '異國短毛貓', '黑貴賓', '西施', '蝴蝶犬+吉娃娃', '柴犬', '吉娃娃約克夏', '鵝', '高砂犬', '迷你杜檳', '潘布魯克', '累杜賓犬', '小太陽', '高加索犬', '黑豬', '哈士奇', '牧羊犬', '美國惡霸', '蘇格蘭梗', '暹羅貓', '三花', '奶油貴賓', '土狼犬', '挪威森林貓', '小杜賓', '德國狼犬', '加菲貓', '牛頭梗', '種貓', '比利時狼犬', '獒犬', '拉不拉多', '麝香豬', '雪納瑞', '臘腸', '法鬥貴賓', '迷你杜賓', '紅貴賓', '靈緹', '藍貓', '高山犬', '吉娃娃', '米格魯', '小型', '比特波士頓犬', '長毛吉娃娃', '蛇', '高山比特', '短毛臘腸', '種犬', '貴賓', '米克斯', '和尚鸚鵡', '鴨', '無', '鬥牛犬', '尋血犬', '狼犬', '比特犬', '長毛', '金吉拉', '可麗牧羊犬', '黑梗犬'}
# BuildName :  {'大', '小', '中'}
# Bodyweight :  {'5~10', '10~15', '0~5', '15~20', '無', '20以上'}
# Age2Name :  {'1至3歲', '3至7歲', '無', '7歲以上', '3至6月齡', '6月齡至1歲', '未離乳', '1至3月齡'}
# CoatName :  {'黃白', '棕黑', '黑棕', '黑黃', '灰', '咖啡黑', '白', '棕灰', '咖啡', '花白', '黑白', '灰白', '咖啡白', '三花', '咖啡棕', '虎斑', '棕', '黑', '花', '棕白', '虎斑白', '米', '黑虎斑', '黑灰', '無', '黃', '灰黑', '黃虎斑'}
# CollarName :  {'有項圈', '無項圈'}
# ThoracodorsalName :  {'有衣服', '無衣服'}
# AdoptionName :  {'暫時不適合', '適合認養'}
# NotAdoptionName :  {'無'}
# _Situation2Name :  {'無', '認養'}
# StatusName :  {'無', '認領養'}
# IsSterilizationName :  {'是', '未確定'}
# EarNoteName :  {'無', '左剪耳', '右剪耳'}
# LengthCoatName :  {'短毛', '無', '中長毛', '長毛', '未修剪過'}
# HealthStatusName :  {'寄生蟲', '正常', '異常', '無', '其它', '疫苗'}
# ShelterName :  {'臺北市動物之家', '新北市政府動物保護防疫處', '臺南市動物之家善化站', '新竹縣公立動物收容所', '宜蘭縣流浪動物中途之家', '桃園市動物保護教育園區', '臺東縣動物收容中心', '基隆市寵物銀行', '金門縣動物收容中心', '新竹市動物保護教育園區', '高雄市燕巢動物保護關愛園區', '新北市八里區公立動物之家', '新北市三芝區公立動物之家', '屏東縣公立犬貓中途之家', '臺南市動物之家灣裡站', '嘉義市動物保護教育園區', '苗栗縣生態保育教育中心(動物收容所)', '新北市新店區公立動物之家', '新北市五股區公立動物之家', '雲林縣流浪動物收容所', '高雄市壽山動物保護教育園區', '花蓮縣流浪犬中途之家', '新北市中和區公立動物之家', '新北市淡水區公立動物之家', '嘉義縣流浪犬中途之家', '彰化縣流浪狗中途之家', '南投縣公立動物收容所', '連江縣流浪犬收容中心', '新北市瑞芳區公立動物之家', '臺中市動物之家南屯園區', '澎湖縣流浪動物收容中心', '無', '新北市板橋區公立動物之家'}
