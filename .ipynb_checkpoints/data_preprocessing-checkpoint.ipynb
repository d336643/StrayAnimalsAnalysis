# %%
import pandas as pd
import numpy as np
import statistics
import datetime
import re

# %%
raw = pd.read_csv("data.csv")
# set(raw.columns)

# %%
#刪掉無資訊、明顯無相關的欄位
saved_columns = [
 'KeyNo',
 'TypeIdName', #('其他', '犬', '貓')
 'AcceptDate', #被領養日期？
 'DistrictTeamName',
 'SexName',#{'none', '公', '未知', '母'}
 'ReasonName',#{nan, '不擬續養', '依法沒入', '其他', '動物救援', '拾獲送交', '收容所轉入', '政府捕捉'}
 'VarietyName',#種類，阿富汗、馬爾濟斯...71種，其中兩個是數字268,269
 'VarietyRemark',#更細的種類，沒有救NaN
 'BuildName',#體型名稱{'1', '中', '大', '小'}
 'Bodyweight',#超亂，setlen=12135, nan, NaN, 13~15, 2公斤, 4....
 'Age2Name',#{'1至3月齡', '1至3歲', '3至6月齡', '3至7歲', '6月齡至1歲', '7歲以上', nan, 'none', '未離乳'}
 'CoatName',#毛色，28種，包括'none'
#  'MouthCoat',#亂，nan,'string', '鼻上方有一咖啡色胎記', '黑嘴','黑嘴    '
#  'HeadCoat',# 亂，set多個nan???
#  'ChestCoat',#亂，nan, 'string'...
#  'FootCoat',#亂，nan, 'string'...
#  'EarCoat',# 亂，set多個nan???
#  'BackCoat',# 亂，set多個nan???
#  'TailCoat',#亂，nan,'string',
 'CollarName',#項圈顏色{'none', '其他', '棕色', '無', '白色', '粉紅色', '紅色', '花色', '藍色', '銀色', '黃色', '黑色'}
#  'CollarRemark',#項圈特徵
 'ThoracodorsalName',#胸甲(衣服)顏色{'none', '其他', '棕色', '無', '白色', '紅色', '花色', '藍色', '黃色', '黑色'}
#  'ThoracodorsalRemark',#多，胸甲(衣服)特徵
 'AdoptionName',#{'待認領', '暫時不適合', '適合認養'}
 'NotAdoptionName',#{'none', '健康不適', '動保案件', '年紀不適', '行為不適'}
 '_Situation2Name',#{'none','人道處理其他法令授權','人道處理第12條第1項第3款','人道處理第12條第1項第5款', '人道處理第12條第1項第7款', '其他','原地飭回','收容所轉出','生理耗弱死亡','疾病死亡','認領','認養','逃脫'}
#  'SituationRemark',#認養狀態備註
 'StatusName',#{'sNull', '其他', '原地飭回', '安樂死', '生理耗弱死亡', '疾病死亡', '認領養', '逃跑'}
#  'Address',
 'IsSterilizationName',#{'是', '未確定'}
#  'SterilizationDate',
 'EarNoteName',#{'none', '右剪耳', '左剪耳'}
#  'Note',#超雜
 'LengthCoatName',#{'none', '中長毛', '未修剪過', '短毛', '長毛'}
 'HealthStatusName',#{'none', '其它', '寄生蟲', '正常', '異常', '疫苗'}
#  'HealthStatusRemark',#超多受傷原因
 'Behavior',#幾種數字，但還不知道數字代表的意思
#  'BehaviorRemark',#超多行為描述
#  'InImage',
#  'ImageNameStr',
#  'FrontImageName',
#  'VaccineDate', #沒填示沒打過疫苗？
 'ShelterName',
#  'VillageID',
#  'VillageName',
 'FinalDate'#領養日期
]
raw = raw[saved_columns]

# %%
#dropna columns
dropna_col = ['FinalDate','ReasonName']
# replacenan_col = ['DistrictTeamName', 'VarietyRemark','Bodyweight',
#                   'MouthCoat','HeadCoat','ChestCoat','FootCoat','EarCoat',
#                   'BackCoat','TailCoat','HealthStatusRemark','BehaviorRemark','CollarRemark',
#                   'ThoracodorsalRemark','SituationRemark','Behavior','VillageName']
print("Before rm na:", raw.shape)

for d_col in dropna_col:
    raw=raw[raw[d_col].notna()]
    print(d_col, raw.shape)
raw.fillna('無', inplace=True)
raw.replace('none', '無', inplace=True)
raw['StatusName'].replace('sNull', '無', inplace=True)
print("Aefore rm na:", raw.shape)
# Out:
# Before rm na: (115267, 25)
# FinalDate (115267, 25)
# ReasonName (115261, 25)
# Aefore rm na: (115261, 25)

# %% [markdown]
# 處理 '_Situation2Name'
#
# 1：'認養'
#
# 0:'無'
#
# 刪掉：'人道處理其他法令授權','人道處理第12條第1項第3款','人道處理第12條第1項第5款', '人道處理第12條第1項第7款','其他','原地飭回','收容所轉出','認領','逃脫','生理耗弱死亡','疾病死亡'
#
# #{'none','人道處理其他法令授權','人道處理第12條第1項第3款','人道處理第12條第1項第5款', '人道處理第12條第1項第7款', '其他','原地飭回','收容所轉出','生理耗弱死亡','疾病死亡','認領','認養','逃脫'}

# %%
tmp = [True if x in ['無', '認養'] else False for x in raw['_Situation2Name']]
raw = raw[tmp]
raw['Adopted'] = [1 if x == "認養" else 0 for x in raw['_Situation2Name']]
print('# of adopted: {} \n# of not adopted:{}'.format(sum(raw['Adopted']), len(raw['Adopted'])-sum(raw['Adopted'])))
# Out:
# # of adopted: 62840
# # of not adopted:8023

# %%
#[Staydays]
raw['AcceptDate'] = [datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S") for x in raw['AcceptDate']] 
raw['FinalDate'] = [datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S") for x in raw['FinalDate']] 
raw["StayDays"] = raw["FinalDate"]-raw['AcceptDate']
raw['StayDays'] = [x.days for x in raw['StayDays']] 
#[Staydays] 清掉未被領養的資料
# raw = raw[raw['StayDays']>=0]
raw['StayDays'] = ["未被領養" if x < 0 else x for x in raw['StayDays']]
raw.drop(columns=['AcceptDate', 'FinalDate'], inplace=True)

#[SexName]clean
raw["SexName"].replace({"none": "未知"}, inplace=True)
#VarietyName=>268,269清掉？

#[BuildName]clean
raw = raw[raw["BuildName"] != '1']
#[VarietyRemark]clean
tmp = [False if x in ['0','MIX','mix','string'] else True for x in raw['VarietyRemark']]
raw = raw[tmp]

print("After cleaning dirty data:", raw.shape)
# Out:
# After cleaning dirty data: (70860, 25)

# %%
#[Bodyweight]clean
tmp = [False if x in ['strin','東22','１',''] else True for x in raw['Bodyweight']]
raw = raw[tmp]
raw['Bodyweight'] = [str(x).replace('K', '').replace('G', '').replace('k', '').replace('g', '').replace('<', '').replace('-', '~').replace('ｋｇ', '').replace('公斤', '').replace('以上', '').replace('以下', '').replace('體重', '').replace('胖', '20').strip(". ") for x in raw['Bodyweight']]
tmp = []
for x in raw['Bodyweight']:
        if x == "無" or x == '':
            tmp.append("無")
            continue
        if x.find("~") != -1:
            tmp.append(statistics.mean([float(y) for y in x.split("~")]))
        else:
            tmp.append(float(x))
raw['Bodyweight'] = tmp
#[Bodyweight]remove outlier
tmp = np.array([x for x in tmp if x != "無"])
Q1= np.mean(tmp)-2*np.std(tmp)
Q3= np.mean(tmp)+2*np.std(tmp)
raw = raw[[True if x == "無" or (x >= Q1 and x <= Q3) else False for x in raw['Bodyweight']]]
#[Bodyweight]convert to category(0~5, 5~10, 10~15...20以上)
tmp = []
for x in raw['Bodyweight']:
    if x == "無":
        tmp.append("無")
    elif x > 0 and x <= 5:
        tmp.append("0~5")
    elif x > 5 and x <= 10:
        tmp.append("5~10")
    elif x > 10 and x <= 15:
        tmp.append("10~15")
    elif x > 15 and x <= 20:
        tmp.append("15~20")
    else:
        tmp.append("20以上")
raw['Bodyweight'] = tmp

print("After cleaning dirty data:", raw.shape)
# Out:
# After cleaning dirty data: (70842, 25)

# %% [markdown]
# # Coat 如何切分特徵，同時有多個特徵？
#
# ### 橘貓很受歡迎？？？

# %%
# #ChestCoat
# raw['ChestCoat'] = ["白毛" if x.find("白")!=-1 else x for x in raw['ChestCoat']] #496 objs
# raw['ChestCoat'] = ["黃毛" if x.find("黃")!=-1 else x for x in raw['ChestCoat']] #7 objs
# raw['ChestCoat'] = ["棕黑毛" if re.search('咖啡|黑|棕', x) else x for x in raw['ChestCoat']] #9 objs
# raw['ChestCoat'] = [x if (x == "無" or re.search('白毛|黃毛|棕黑毛', x)) else "其他" for x in raw['ChestCoat']]
# print("ChestCoat:")
# for i in set(raw['ChestCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['ChestCoat']]))
# print()

# #MouthCoat
# raw['MouthCoat'] = ["白" if x.find("白")!=-1 else x for x in raw['MouthCoat']] #117 objs
# raw['MouthCoat'] = ["黃" if x.find("黃")!=-1 else x for x in raw['MouthCoat']] #9 objs
# raw['MouthCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x) else x for x in raw['MouthCoat']] #242 objs
# raw['MouthCoat'] = [x if (x == "無" or re.search('白|黃|棕灰黑', x)) else "其他" for x in raw['MouthCoat']]
# print("MouthCoat:")
# for i in set(raw['MouthCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['MouthCoat']]))
# print()

# #HeadCoat
# raw['HeadCoat'] = ["虎斑" if re.search('虎斑|虎班', x) else x for x in raw['HeadCoat']] #23 objs
# raw['HeadCoat'] = ["黑白" if re.search('黑.*白', x) else x for x in raw['HeadCoat']] #4 objs
# raw['HeadCoat'] = ["棕灰黑" if (re.search('咖啡|黑|棕|灰', x) and x != "黑白") else x for x in raw['HeadCoat']] #41 objs
# raw['HeadCoat'] = ["受傷" if re.search('傷|浮腫|受傷|車禍|獨眼|白內障', x) else x for x in raw['HeadCoat']] #10 objs
# raw['HeadCoat'] = ["四眼" if re.search('四目|四眼', x) else x for x in raw['HeadCoat']] #66 objs
# raw['HeadCoat'] = ["白" if (x.find("白")!=-1 and x != "黑白") else x for x in raw['HeadCoat']] #18 objs
# raw['HeadCoat'] = ["黃" if x.find("黃")!=-1 else x for x in raw['HeadCoat']] #29 objs
# raw['HeadCoat'] = [x if (x == "無" or re.search('虎斑|黑白|棕灰黑|受傷|四眼|白|黃', x)) else "其他" for x in raw['HeadCoat']]
# print("HeadCoat:")
# for i in set(raw['HeadCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['HeadCoat']]))
# print()

# #FootCoat
# raw['FootCoat'] = ["受傷" if re.search('傷|截|不良於行|骨折|斷裂|缺|腫瘤|斷|脫臼|尺骨外露|跛行|三腳|後癱|癱瘓|畸形|短|無力', x) else x for x in raw['FootCoat']] #10 objs
# raw['FootCoat'] = ["虎斑" if re.search('虎斑|虎班|斑紋', x) else x for x in raw['FootCoat']] #23 objs
# raw['FootCoat'] = ["白" if x.find("白")!=-1 else x for x in raw['FootCoat']] #18 objs
# raw['FootCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x) else x for x in raw['FootCoat']] #23 objs
# raw['FootCoat'] = ["黃" if x.find("黃")!=-1 else x for x in raw['FootCoat']] #18 objs
# raw['FootCoat'] = [x if (x == "無" or re.search('虎斑|白|棕灰黑|受傷|黃', x)) else "其他" for x in raw['FootCoat']]
# print("FootCoat:")
# for i in set(raw['FootCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['FootCoat']]))
# print()

# #EarCoat
# raw['EarCoat'] = ["剪/缺/折/立/垂耳" if re.search('垂|剪|折|缺|立|摺|聳', x) else x for x in raw['EarCoat']] #10 objs
# raw['EarCoat'] = ["受傷" if re.search('左耳皺|皮膚炎|長瘤', x) else x for x in raw['EarCoat']] #23 objs
# raw['EarCoat'] = ["虎斑" if re.search('虎斑|虎班|斑紋', x) else x for x in raw['EarCoat']] #23 objs
# raw['EarCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x) else x for x in raw['EarCoat']] #23 objs
# raw['EarCoat'] = ["黃" if x.find("黃")!=-1 else x for x in raw['EarCoat']] #18 objs
# raw['EarCoat'] = [x if (x == "無" or re.search('虎斑|缺|棕灰黑|受傷|黃', x)) else "其他" for x in raw['EarCoat']]
# print("EarCoat:")
# for i in set(raw['EarCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['EarCoat']]))
# print()

# #BackCoat
# raw['BackCoat'] = ["受傷" if re.search('皮膚病|傷|突出物', x) else x for x in raw['BackCoat']]
# raw['BackCoat'] = ["斑點" if re.search('虎斑|虎班|斑紋|斑', x) else x for x in raw['BackCoat']]
# raw['BackCoat'] = ["白" if re.search('白', x) else x for x in raw['BackCoat']]
# raw['BackCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x)  else x for x in raw['BackCoat']] 
# raw['BackCoat'] = [x if (x == "無" or re.search('斑點|棕灰黑|受傷|白', x)) else "其他" for x in raw['BackCoat']]
# print("BackCoat:")
# for i in set(raw['BackCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['BackCoat']]))
# print()

# #TailCoat
# raw['TailCoat'] = ["有病" if re.search('皮膚病|肉瘤', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["截尾" if re.search('截|剪尾|半短|折尾|斷|短|半尾', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["無尾" if re.search('無尾', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["斑點" if re.search('虎斑|虎班|斑紋|斑', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["麒麟尾" if re.search('麒麟', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["鐮刀尾" if re.search('鐮刀', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["白" if re.search('白', x) else x for x in raw['TailCoat']]
# raw['TailCoat'] = ["棕灰黑" if re.search('咖啡|黑|棕|灰', x)  else x for x in raw['TailCoat']] 
# raw['TailCoat'] = [x if (x == "無" or re.search('斑點|棕灰黑|有病|白|截尾|無尾|麒麟尾|鐮刀尾', x)) else "其他" for x in raw['TailCoat']]
# print("TailCoat:")
# set(raw['TailCoat'])
# for i in set(raw['TailCoat']):
#     print(i, sum([True if re.search(i, x) else False for x in raw['TailCoat']]))
# print()

# %%
#有無項圈
raw['CollarName'] = ["無項圈" if x == "無" else "有項圈" for x in raw['CollarName']]
#有無衣服
raw['ThoracodorsalName'] = ["無衣服" if x == "無" else "有衣服" for x in raw['ThoracodorsalName']]

# %% [markdown]
# # NotAdoptionName有標注的欄位都刪掉？ //欄位留著

# %%
#每隻動物都被領養了嗎？？？因為有NotAdoptionName這個欄位
# print(set(raw['NotAdoptionName']))
# raw = raw[raw['NotAdoptionName']=='無']
# print("rm [NotAdoptionName], data shape", raw.shape)

# %% [markdown]
# # SituationRemark有標注的欄位都刪掉？ ////欄位刪掉

# %%
# print(set(raw['SituationRemark']))
# raw = raw[raw['SituationRemark']=='無']
# print("rm [SituationRemark], data shape", raw.shape)

# %% [markdown]
# # IsSterilizationName'填的有{'是', '未確定'}，填是的有14834筆，SterilizationDate 有填的9961筆
#
#
# ### 要保留IsSterilizationName這個欄位就好嗎？

# %%
# print(sum([True if x!='0001-01-01T00:00:00' else False for x in raw['SterilizationDate']]))
# print(sum([True if x=='是' else False for x in raw['IsSterilizationName']]))
# set(raw['SterilizationDate'])

# %% [markdown]
# #  備註欄位直接刪掉？內容大致為三類（病因、外觀、各種阿里阿咂），其中病因佔多數

# %%
# print(sum([True if x=='無' else False for x in raw['Note']]))
# set(raw['Note'])

# %%
# set(raw['HealthStatusName'])
# print(sum([True if x=='無' else False for x in raw['HealthStatusName']]))

# %% [markdown]
# #  健康狀態備註欄位直接刪掉？
# - 絕育(佔多數)(紮)
# - 病因or缺陷
# - 疫苗（CCV\CPV\FIV\五合一）
# - 驅蟲藥
# - 幼犬奶貓

# %%
# set(raw['HealthStatusRemark'])
# print(sum([True if x=='無' else False for x in raw['HealthStatusRemark']]))

# %% [markdown]
# # [Behavior]可以有多種category，切成01表

# %%
tmp = []
for a in raw['Behavior']:
    tmp += [x for x in a.split(", ")]
health_types = set(tmp)
for i in health_types:
    health_types_col = []
    for a in raw['Behavior']:
        if i in a:
            health_types_col.append(1)
        else:
            health_types_col.append(0)
    raw['Behavior'+i] = health_types_col
raw.drop(columns=['Behavior','Behavior無'], inplace=True)

# %%
file = open('clean1_description.txt', 'w')
file.write('# of columns:'+str(len(raw.columns)))
raw = raw.astype(str)
for col in raw.columns:
    if col in ['ＳInImage','ImageNameStr','FrontImageName']:
        continue
    print(col+' : ', set(raw[col]))
    file.write(col+' : '+', '.join(list(set(raw[col])))+'\n')
#     print(i, sum([True if re.search(i, x) else False for x in raw['TailCoat']]))
file.write("# of adopted data:{}".format(sum(raw['Adopted']=='1'))+'\n')
file.write("# of not adopted data:{}".format(sum(raw['Adopted']=='0'))+'\n')
file.close()
raw.to_csv('clean1.csv', index=False)
# Out:
# KeyNo :  {'117348', '28930', '53826', '37348', '114056', '87555', '153577', '123693', '122689', '48396', '79705', '87064', '37731', '48326', '72559', '103672', '91441', '144330', '108564', '153204', '49915', '62038', '117700', '44139', '53628', '62243', '42927', '69013', '69660', '132957', '129874', '88532', '103725', '72356', '29124', '43826', '84353', '28418', '71999', '72222', '131295', '153552', '152174', '86766', '32257', '63158', '92123', '46713', '83872', '117915', '101038', '148590', '148691', '50685', '48312', '51423', '111394', '122894', '100528', '117603', '107000', '69539', '101345', '155618', '115609', '91788', '44724', '142678', '160182', '96068', '92055', '66545', '152264', '63480', '82889', '151076', '106573', '76800', '62622', '48301', '112575', '158987', '72850', '147658', '96699', '53033', '34867', '53083', '152504', '67723', '44048', '71665', '97755', '41622', '133895', '35240', '138316', '34206', '72334', '91093', '44025', '93732', '78608', '118483', '77791', '123868', '83673', '66537', '115490', '86242', '150710', '157661', '108636', '44708', '125504', '46640', '50111', '151741', '65199', '141463', '55144', '63061', '49272', '99258', '70090', '44489', '40239', '48869', '121484', '46701', '58940', '73157', '106720', '65420', '52203', '76825', '72866', '68809', '27628', '28813', '125277', '126834', '131213', '92059', '158784', '29746', '32731', '144516', '42522', '121431', '96412', '104805', '131552', '160631', '43560', '40145', '54527', '143074', '147568', '153559', '158485', '157478', '117097', '71652', '51873', '77038', '55726', '111502', '55792', '69879', '110869', '27620', '143797', '59262', '38201', '58003', '144281', '107698', '82148', '51171', '69424', '74663', '105312', '64496', '111917', '93534', '113988', '50088', '120154', '75681', '51410', '64650', '36680', '133368', '91008', '120356', '73047', '48466', '27614', '88729', '103630', '138146', '84632', '159844', '83104', '40886', '49143', '50455', '113332', '127146', '160214', '62467', '87875', '116395', '62385', '96262', '107681', '130018', '152740', '92254', '95472', '108327', '49264', '30710', '77387', '40805', '151658', '84250', '160332', '72975', '96676', '93374', '131713', '55016', '47786', '84001', '117174', '151753', '153553', '53498', '131636', '30410', '152967', '59373', '108723', '145901', '82085', '103235', '33522', '104957', '139544', '96842', '60978', '142634', '160511', '45919', '146925', '79721', '112564', '159396', '99646', '62949', '116469', '139715', '47605', '70961', '148339', '44375', '41574', '110924', '92008', '90359', '94148', '32256', '50357', '72192', '128685', '41062', '152693', '91435', '30798', '155763', '139170', '146904', '82389', '111138', '111141', '159639', '136606', '46569', '40486', '124221', '48717', '66016', '79165', '99226', '90735', '106067', '142210', '147144', '90521', '82219', '121629', '65022', '125796', '154078', '97383', '51397', '112812', '106235', '53782', '144316', '148254', '61122', '70500', '41316', '116231', '126060', '121706', '40795', '74509', '74993', '126814', '106637', '69841', '77790', '144532', '153511', '97870', '67412', '61011', '65013', '93564', '106590', '160197', '106475', '110253', '52137', '92077', '109859', '41710', '106807', '159917', '63328', '36233', '128515', '159433', '127459', '64166', '125415', '158995', '50403', '129894', '51125', '35142', '123247', '155905', '34000', '80378', '79770', '62075', '105740', '106046', '111346', '115279', '160595', '129788', '141718', '59688', '121580', '58645', '109896', '88793', '37071', '52487', '97581', '36441', '87260', '35025', '42463', '137640', '62138', '28963', '159279', '71330', '41124', '107829', '118326', '67216', '88660', '90043', '42986', '102459', '75420', '153310', '55483', '118664', '129986', '75263', '98456', '38213', '88363', '92788', '82090', '110246', '148338', '65674', '30311', '105353', '147122', '108492', '27887', '112633', '32298', '36152', '144593', '51266', '44121', '155479', '60979', '35777', '61349', '78062', '98645' ...
# TypeIdName :  {'其他', '犬', '貓'}
# DistrictTeamName :  {'林內鄉', '關山鎮', '大溪區', '大湖鄉', '秀林鄉', '雙溪區', '水林鄉', '二水鄉', '板橋區', '北港鎮', '五結鄉', '宜蘭市', '九如鄉', '鼓山區', '萬巒鄉', '暖暖區', '霧峰區', '二林鎮', '林園區', '北竿鄉', '貢寮區', '金湖鎮', '枋山鄉', '田寮區', '六甲區', '金沙鎮', '田尾鄉', '安平區', '番路鄉', '中和區', '造橋鄉', '苑裡鎮', '新港鄉', '琉球鄉', '大武鄉', '新興區', '花蓮市', '大城鄉', '中壢區', '三義鄉', '石岡區', '和美鎮', '羅東鎮', '鳥松區', '水上鄉', '埤頭鄉', '旗山區', '鹽埔鄉', '鹿谷鄉', '桃源區', '淡水區', '烏來區', '信義鄉', '瑞芳區', '小港區', '山上區', '名間鄉', '梧棲區', '芎林鄉', '梅山鄉', '楠西區', '獅潭鄉', '南澳鄉', '玉里鎮', '深坑區', '卑南鄉', '新市區', '竹塘鄉', '水里鄉', '大里區', '太麻里鄉', '苗栗市', '新店區', '員山鄉', '寶山鄉', '大埤鄉', '仁武區', '麟洛鄉', '南州鄉', '湖內區', '潮州鎮', '公館鄉', '長治鄉', '馬公市', '東引鄉', '平鎮區', '橋頭區', '民雄鄉', '大同鄉', '萬華區', '三芝區', '元長鄉', '社頭鄉', '樹林區', '清水區', '臺西鄉', '崙背鄉', '埔鹽鄉', '湖西鄉', '泰安鄉', '金山區', '安南區', '綠島鄉', '路竹區', '復興區', '中寮鄉', '大社區', '獅子鄉', '竹南鎮', '美濃區', '梓官區', '南化區', '屏東市', '關廟區', '玉井區', '無', '冬山鄉', '頭城鎮', '吉安鄉', '北區', '莒光鄉', '瑞穗鄉', '東河鄉', '南港區', '布袋鎮', '西嶼鄉', '下營區', '新園鄉', '彌陀區', '芬園鄉', '芳苑鄉', '臺東市', '外埔區', '蘆竹區', '東山區', '中區', '信義區', '阿里山鄉', '三灣鄉', '八里區', '左鎮區', '燕巢區', '新埔鎮', '義竹鄉', '後壁區', '來義鄉', '光復鄉', '北投區', '橫山鄉', '六龜區', '大林鎮', '枋寮鄉', '溪湖鎮', '溪口鄉', '文山區', '北斗鎮', '南投市', '甲仙區', '大雅區', '北屯區', '通霄鎮', '南區', '白沙鄉', '南屯區', '太平區', '金峰鄉', '新營區', '永安區', '內門區', '口湖鄉', '鶯歌區', '車城鄉', '茄萣區', '新城鄉', '金寧鄉', '東港鎮', '三星鄉', '竹崎鄉', '峨眉鄉', '阿蓮區', '士林區', '內埔鄉', '其他', '官田區', '員林市', '烏日區', '八德區', '尖石鄉', '線西鄉', '岡山區', '那瑪夏區', '歸仁區', '鳳山區', '朴子市', '杉林區', '三民區', '關西鎮', '將軍區', '龍潭區', '中山區', '成功鎮', '中西區', '旗津區', '東勢鄉', '南庄鄉', '龍崎區', '學甲區', '礁溪鄉', '竹田鄉', '南竿鄉', '楠梓區', '魚池鄉', '麻豆區', '三峽區', '林口區', '花壇鄉', '竹北市', '金城鎮', '香山區', '壯圍鄉', '里港鄉', '萬丹鄉', '萬榮鄉', '和平區', '大樹區', '新屋區', '龍井區', '大同區', '觀音區', '后里區', '斗六市', '田中鎮', '東石鄉', '竹東鎮', '高樹鄉', '中埔鄉', '大安區', '永和區', '大甲區', '土城區', '土庫鎮', '虎尾鎮', '鹽水區', '新莊區', '達仁鄉', '麥寮鄉', '北門區', '東勢區', '二崙鄉', '褒忠鄉', '卓蘭鎮', '烏坵鄉', '四湖鄉', '內湖區', '埔心鄉', '延平鄉', '中正區', '前鎮區', '埔里鎮', '古坑鄉', '湖口鄉', '大肚區', '七股區', '太保市', '西港區', '恆春鎮', '茂林區', '善化區', '汐止區', '石門區', '永康區', '新化區', '大寮區', '烈嶼鄉', '鳳林鎮', '新豐鄉', '池上鄉', '西湖鄉', '潭子區', '三重區', '安樂區', '仁愛區', '頭份市', '神岡區', '長濱鄉', '五股區', '沙鹿區', '新社區', '蘆洲區', '北埔鄉', '鹿草鄉', '西屯區', '松山區', '西螺鎮', '永靖鄉', '斗南鎮', '後龍鎮', '福興鄉', '萬里區', '望安鄉', '鹽埕區', '彰化市', '大村鄉', '西區', '頭屋鄉', '仁德區', '壽豐鄉', '新埤鄉', '蘇澳鎮', '龜山區', '大內區', '石碇區', '平溪區', '佳里區', '七堵區', '草屯鎮', '柳營區', '溪州鄉', '銅鑼鄉', '鹿野鄉', '竹山鎮', '白河區', '泰山區', '海端鄉', '牡丹鄉', '三地門鄉', '苓雅區', '六腳鄉', '坪林區', '國姓鄉', '桃園區', '楊梅區', '豐濱鄉', '安定區', '東區', '莿桐鄉', '秀水鄉', '左營區', '豐原區', '伸港鄉', '鹿港鎮', '集集鎮', '大園區', '仁愛鄉', '前金區'}
# SexName :  {'母', '未知', '無', '公'}
# ReasonName :  {'動物救援', '依法沒入', '不擬續養', '其他', '拾獲送交', '收容所轉入', '政府捕捉'}
# VarietyName :  {'杜賓', '迷你品', '其他貓', '寵物兔', '英國藍貓', '拉薩', '波斯', '邊境牧羊犬', '黃金獵犬', '馬爾濟斯', '摺耳貓', '高山犬', '波士頓', '可卡', '豹貓', '268', '古代牧羊犬', '柯基', '吉娃娃', '269', '英國短毛貓', '柴犬', '暹羅貓', '金吉拉', '哈士奇', '拉布拉多', '比熊', '混種', '混種貓', '博美', '喜樂蒂', '比特', '美國短毛貓', '蝴蝶犬', '貴賓', '牛頭梗', '獵狐梗', '狐狸', '大白熊', '俄羅斯藍貓', '折耳貓', '英國查理士獵犬', '挪威納', '梗犬', '狼犬', '其他犬', '法國鬥牛犬', '混種狗', '臘腸', '敖犬', '鬆獅犬', '西高地白梗', '傑克羅素', '大丹狗', '米格魯', '西施', '北京犬', '寵物鼠', '拳師犬', '秋田', '英國鬥牛犬', '巴戈', '約克夏', '美國鬥牛犬', '加菲貓', '雪納瑞'}
# VarietyRemark :  {'混狼犬', '狐狸犬', '鵝4隻', '柴', '杜賓', '類柴犬', '麝香豬', '混臘腸', '孟加拉豹貓', '混種品種犬', '小杜賓', '暹羅貓', '鴿子', '吉娃娃混約克夏', '比特混波士頓犬', '日本狆', '蝴蝶犬+吉娃娃', '似梗犬', '似柴犬', '水牛', '混種貓(美短+豹貓)', '蛇', '牛頭梗', '似吉娃娃', '米克斯', '奶油貴賓', '鸚鵡', '似臘腸', '混雪納瑞', '高加索犬', '年老', '混種柴', '狼犬', '黑貴賓', '混種狗', '喜馬拉雅貓', '鵝', '短毛臘腸', '混種犬', '銀', '比利時狼犬', '貂', '似馬爾濟斯', '鬥牛犬', '混種臘腸', '微混比特犬', '迷你品', '黑豬', '很像混種犬', '高山犬', '黑梗犬', '紅貴賓', '俄國藍貓', '尋血犬', '混種', '混種狼犬', '比特犬', '混吉娃娃', '蘇格蘭梗', '梗血統', '混秋田', '牧羊犬', '混牧羊犬', '梗犬', '混梗犬', '巴及度', '凱門鱷', '混迷你杜賓', '查理氏  ', '西施', '混種梗犬', '孔雀', '查理士', '混種比特', '刺蝟', '波音達', '潘布魯克', '混比特犬', '雪納瑞', '似大麥町', '長毛吉娃娃', '無', '和尚鸚鵡', '疑似混到高砂犬', '混高山犬', '品種說明', '挪威森林貓', '混西施', '查理士 ', '法鬥混貴賓', '混哈士奇', '似比特 ', '廠商測試', '吉娃娃', '金吉拉', '長毛', '混比 特', '羊', '似西施', '似吉娃娃 ', '德國狼犬', '累似杜賓犬', '喜樂蒂', '可能混到德國狼犬', '喜馬拉雅', '類高山混比特', '異國短毛貓', '高加索', '松鼠', '小型', '混暹羅', '混獒犬', '混梗', '黑色', '赫尼亞', '拉不拉多', '混美短', '狼犬混哈士奇', '可麗牧羊犬', '長毛臘腸', '柯基犬', '有混到狼犬', '波斯', '長毛臘腸犬', '土狼犬', '小太陽', '獒犬', '迷你杜賓', '兔子', '蜜袋鼯', '藍貓', '柴犬', '鬥牛', '似牧羊犬', '黑色貴賓', '混種貓', '混貴賓', '似比特', '比特', '迷你杜檳', '混米格魯', '貴賓', '靈緹', '鴨', '混杜賓', '混種瑪加吉娃娃', '混柴犬', '吸蜜鸚鵡', '美國惡霸', '白鼻心', '和尚', '似拉不拉', '三花', '加菲貓', '白底，頭尾有花色'}
# BuildName :  {'中', '小', '大'}
# Bodyweight :  {'無', '20以上', '0~5', '5~10', '10~15', '15~20'}
# Age2Name :  {'無', '未離乳', '1至3月齡', '7歲以上', '6月齡至1歲', '3至6月齡', '1至3歲', '3至7歲'}
# CoatName :  {'無', '咖啡', '咖啡黑', '黑灰', '黃虎斑', '灰', '花白', '灰黑', '棕白', '黃', '咖啡棕', '棕', '米', '黑白', '灰白', '黑黃', '黃白', '黑', '花', '白', '黑棕', '咖啡白', '黑虎斑', '棕灰', '虎斑', '虎斑白', '棕黑', '三花'}
# CollarName :  {'有項圈', '無項圈'}
# ThoracodorsalName :  {'有衣服', '無衣服'}
# AdoptionName :  {'暫時不適合', '待認領', '適合認養'}
# NotAdoptionName :  {'無', '行為不適', '動保案件', '健康不適', '年紀不適'}
# _Situation2Name :  {'認養', '無'}
# StatusName :  {'無', '其他', '原地飭回', '認領養'}
# IsSterilizationName :  {'是', '未確定'}
# EarNoteName :  {'左剪耳', '無', '右剪耳'}
# LengthCoatName :  {'長毛', '無', '中長毛', '短毛', '未修剪過'}
# HealthStatusName :  {'無', '其它', '疫苗', '正常', '異常', '寄生蟲'}
# ShelterName :  {'苗栗縣生態保育教育中心(動物收容所)', '無', '臺中市動物之家南屯園區', '基隆市寵物銀行', '臺北市動物之家', '連江縣流浪犬收容中心', '澎湖縣流浪動物收容中心', '測試收容所', '屏東縣公立犬貓中途之家', '新北市五股區公立動物之家', '高雄市燕巢動物保護關愛園區', '新北市政府動物保護防疫處', '新北市瑞芳區公立動物之家', '新北市三芝區公立動物之家', '南投縣公立動物收容所', '雲林縣流浪動物收容所', '新北市中和區公立動物之家', '彰化縣流浪狗中途之家', '嘉義市動物保護教育園區', '新北市板橋區公立動物之家', '新北市八里區公立動物之家', '新北市淡水區公立動物之家', '新竹縣公立動物收容所', '新北市新店區公立動物之家', '臺東縣動物收容中心', '臺南市動物之家善化站', '高雄市壽山動物保護教育園區', '新竹市動物保護教育園區', '金門縣動物收容中心', '臺南市動物之家灣裡站', '桃園市動物保護教育園區', '宜蘭縣流浪動物中途之家', '嘉義縣流浪犬中途之家', '花蓮縣流浪犬中途之家'}
# Adopted :  {'0', '1'}
# StayDays :  {'1137', '122', '882', '482', '577', '701', '865', '994', '740', '228', '69', '915', '1118', '88', '217', '575', '799', '967', '435', '646', '1048', '885', '1065', '925', '600', '1234', '667', '574', '1215', '282', '1046', '17', '648', '831', '2', '337', '1155', '404', '698', '343', '538', '1105', '306', '434', '588', '147', '1590', '931', '955', '1479', '949', '739', '547', '39', '1168', '689', '1179', '822', '1050', '894', '844', '1102', '381', '84', '832', '486', '811', '859', '640', '370', '555', '509', '650', '466', '335', '323', '103', '682', '559', '102', '745', '523', '423', '223', '229', '820', '430', '63', '1226', '458', '395', '34', '932', '80', '533', '371', '833', '1001', '219', '520', '178', '210', '582', '233', '109', '350', '651', '1073', '280', '786', '389', '270', '47', '130', '218', '459', '418', '1066', '481', '187', '1435', '139', '1076', '457', '693', '161', '191', '436', '172', '35', '975', '703', '603', '524', '104', '359', '805', '383', '1639', '96', '207', '922', '392', '299', '275', '813', '1018', '527', '296', '888', '1614', '2052', '961', '317', '408', '1029', '391', '157', '205', '995', '673', '580', '489', '174', '399', '244', '1043', '645', '626', '258', '1529', '979', '737353', '807', '438', '474', '1079', '906', '263', '349', '181', '1054', '1377', '454', '1213', '146', '77', '378', '308', '1090', '1422', '117', '716', '318', '44', '1127', '818', '197', '192', '78', '1607', '1371', '1264', '182', '243', '711', '407', '900', '724', '442', '166', '237', '548', '1336', '728', '884', '200', '483', '858', '273', '125', '7', '893', '320', '212', '285', '918', '176', '414', '923', '1270', '856', '1009', '348', '628', '145', '692', '162', '440', '420', '758', '546', '1246', '364', '352', '37', '363', '374', '305', '74', '179', '61', '614', '717', '669', '106', '634', '802', '804', '85', '491', '267', '415', '765', '1059', '173', '1027', '115', '193', '247', '513', '45', '1108', '1033', '727', '621', '1074', '347', '461', '50', '789', '98', '422', '1830', '465', '184', '361', '537', '1156', '216', '365', '376', '501', '729', '156', '86', '112', '784', '479', '625', '234', '476', '432', '65', '351', '750', '661', '379', '1877', '1532', '424', '344', '68', '767', '929', '304', '610', '369', '694', '668', '429', '171', '204', '431', '970', '1279', '152', '227', '796', '144', '658', '902', '572', '1192', '1324', '672', '367', '127', '666', '816', '163', '169', '170', '769', '718', '593', '887', '97', '468', '403', '541', '654', '455', '413', '629', '495', '385', '490', '467', '1338', '1223', '29', '983', '33', '451', '1482', '448', '568', '868', '766', '1273', '862', '388', '1', '209', '1020', '195', '655', '417', '198', '530', '964', '27', '390', '136', '1827', '254', '735', '382', '652', '355', '89', '4', '278', '9', '623', '142', '927', '1010', '945', '1120', '1393', '899', '609', '256', '353', '307', '456', '18', '221', '380', '190', '325', '321', '301', '662', '959', '726', '1022', '504', '1367', '570', '596', '108', '665', '500', '439', '788', '441', '636', '463', '1008', '426', '283', '1786', '1454', '710', '2107', '101', '230', '757', '586', '159', '473', '330', '185', '825', '366', '400', '488', '830', '99', '512', '449', '0', '276', '965', '90', '763', '797', '358', '708', '未被領養', '958', '855', '612', '75', '643', '892', '311', '272', '14', '853', '969', '1696', '342', '742', '406', '1449', '569', '471', '327', '507', '635', '472', '876', '1554', '21', '360', '354', '951', '333', '1186', '516', '375', '539', '446', '290', '140', '762', '966', '484', '264', '1266', '992', '300', '141', '12', '748', '1062', '819', '647', '511', '167', '1007', '632', '1841', '444', '107', '690', '595', '10', '405', '6', '79', '622', '606', '660', '883', '505', '551', '480', '450', '23', '774', '502', '499', '38', '1572', '249', '148', '412', '1205', '131', '123', '384', '532', '518', '419', '266', '303', '42', '322', '15', '203', '55', '120', '508', '709', '339', '73', '630', '736714', '514', '49', '20', ...
# Behavior84 :  {'0', '1'}
# Behavior85 :  {'0', '1'}
# Behavior90 :  {'0', '1'}
# Behavior89 :  {'0', '1'}
# Behavior87 :  {'0', '1'}
# Behavior83 :  {'0', '1'}
# Behavior88 :  {'0', '1'}
# Behavior86 :  {'0', '1'}

# %%
print("# of adopted data:{}".format(sum(raw['Adopted']=='1')))
print("# of not adopted data:{}".format(sum(raw['Adopted']=='0')))
# Out:
# # of adopted data:62820
# # of not adopted data:8022
